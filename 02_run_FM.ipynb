# %%
setwd("/mnt/lareaulab/reliscu/projects/NSF_GRFP/analyses/bulk/hahn_2023/cortex")

library(dplyr)
library(data.table)

source("/mnt/lareaulab/reliscu/code/FindModules/FindModules.R")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Loading required package: dynamicTreeCut
#
# Loading required package: fastcluster
#
#
# Attaching package: ‘fastcluster’
#
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
#
#
# Attaching package: ‘WGCNA’
#
#
# The following object is masked from ‘package:stats’:
#
#     cor
#
#
#
# Attaching package: ‘flashClust’
#
#
# The following object is masked from ‘package:fastcluster’:
#
#     hclust
#
#
# The following object is masked from ‘package:stats’:
#
#     hclust
#
#
#
# Attaching package: ‘svMisc’
#
#
# The following object is masked from ‘package:utils’:
#
#     ?
#
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘qvalue’
#
#
# The following object is masked from ‘package:WGCNA’:
#
#     qvalue
#
#
#
# Attaching package: ‘ellipse’
#
#
# The following object is masked from ‘package:graphics’:
#
#     pairs
#
#
#
# Attaching package: ‘purrr’
#
#
# The following object is masked from ‘package:data.table’:
#
#     transpose
# Allowing multi-threading with up to 48 threads.

# %% [markdown]
# Here I run FM to (hopefully) find modules representing each of the cell types present in the single-cell data

# %% [markdown]
# ## Run FM on hahn_2023_cortex_STAR_counts_TMMF_All_130_outliers_removed

# %%
expr <- fread("hahn_2023_cortex_STAR_counts_TMMF_SampleNetworks/All_03-44-55/hahn_2023_cortex_STAR_counts_TMMF_All_130_outliers_removed.csv", data.table=FALSE)

# For duplicate genes, choose row with highest mean expression

mean_expr <- data.frame(
    Index=1:nrow(expr), 
    Gene=expr[,1], 
    Expr=rowMeans(expr[,-1])
)

mean_expr <- mean_expr %>%
    group_by(Gene) %>%
    slice_max(Expr, with_ties=FALSE)

print(dim(mean_expr))

expr <- expr[mean_expr$Index,]
# Out:
# [1] 53326     3

# %%
colnames(expr)[1] <- "Gene"

# %%
# Order samples by covariates of interest

sampleinfo <- read.csv("/mnt/lareaulab/reliscu/projects/NSF_GRFP/data/bulk/hahn_2023/cortex/hahn_2023_cortex_sampleinfo.csv")
sampleinfo <- sampleinfo %>%
    arrange(age, sex_y)
sampleinfo <- sampleinfo[sampleinfo$Run %in% colnames(expr),]
    
expr <- expr[, c(1, match(sampleinfo$Run, colnames(expr)[-1]) + 1)]
all.equal(sampleinfo$Run, colnames(expr)[-1])
# Out:
# [1] TRUE

# %%
# Encountering errors when calculating distance in FM; problem seems related to some genes having 0 MAD (median absolute deviation)

# Filtering these in advance:

X <- as.matrix(expr[,-1])
mads <- apply(X, 1, mad, na.rm = TRUE)
bad  <- which(!is.finite(mads) | mads == 0)

length(bad)
head(expr[,1][bad])

mask <- mads > 0
expr <- expr[mask,]
# Out:
# [1] 25527
# [1] "0610006L08Rik" "0610012D04Rik" "0610025J13Rik" "0610031O16Rik"
# [5] "0610033M10Rik" "0610039K10Rik"

# %%
dim(expr)
# Out:
# [1] 27799   131

# %%
# Subset to genes in the top X percentile for generating modules

prob <- .2
mean_expr <- rowMeans(expr[,-1])

subset_cutoff <- unname(quantile(mean_expr, prob))
print(paste("quantile(mean_expr, prob):", round(subset_cutoff, 3)))
subset <- mean_expr >= subset_cutoff
sum(subset)
# Out:
# [1] "quantile(mean_expr, prob): 4.59"
# [1] 19459

# %%
samplegroups <- as.factor(sampleinfo$age)
merge.param <- 0.95
signumvec <- c(.9,.89,.88,.87,.86,.85,.84)
projectname <- paste0("hahn_2023_cortex_STAR_counts_TMMF_All_130_outliers_removed", "_mergeParam", merge.param, "_minSignum", min(signumvec), "_subsetCutoff", round(subset_cutoff, 3))

# %%
FindModules(
  projectname=projectname,
  expr=expr,
  geneinfo=1,
  sampleindex=2:ncol(expr),
  samplegroups=samplegroups,
  subset=subset,
  simMat=NULL,
  saveSimMat=FALSE,
  simType="Bicor",
  beta=1,
  overlapType="None",
  TOtype="signed",
  TOdenom="min",
  MIestimator="mi.mm",
  MIdisc="equalfreq",
  signumType="rel",
  iterate=TRUE,
  signumvec=signumvec, 
  minsizevec=c(3,4,6,8,10), 
  signum=NULL,
  minSize=NULL,
  merge.by="ME",
  merge.param=merge.param,
  export.merge.comp=T,
  ZNCcut=2,
  calcSW=FALSE,
  loadTree=FALSE,
  writeKME=TRUE,
  calcBigModStat=FALSE,
  writeModSnap=TRUE
)

# %% [markdown]
# ## Run FM on hahn_2023_cortex_STAR_TPM_All_94_outliers_removed

# %%
expr <- fread("hahn_2023_cortex_STAR_TPM_SampleNetworks/All_09-53-50/hahn_2023_cortex_STAR_TPM_All_94_outliers_removed.csv", data.table=FALSE)

# For duplicate genes, choose row with highest mean expression

mean_expr <- data.frame(
    Index=1:nrow(expr), 
    Gene=expr[,1], 
    Expr=rowMeans(expr[,-1])
)

mean_expr <- mean_expr %>%
    group_by(Gene) %>%
    slice_max(Expr, with_ties=FALSE)

print(dim(mean_expr))

expr <- expr[mean_expr$Index,]

# %%
colnames(expr)[1] <- "Gene"

# %%
# Order samples by covariates of interest

sampleinfo <- read.csv("/mnt/lareaulab/reliscu/projects/NSF_GRFP/data/bulk/hahn_2023/cortex/hahn_2023_cortex_sampleinfo.csv")
sampleinfo <- sampleinfo %>%
    arrange(age, sex_y)
sampleinfo <- sampleinfo[sampleinfo$Run %in% colnames(expr),]
    
expr <- expr[, c(1, match(sampleinfo$Run, colnames(expr)[-1]) + 1)]
all.equal(sampleinfo$Run, colnames(expr)[-1])

# %%
# Encountering errors when calculating distance in FM; problem seems related to some genes having 0 MAD (median absolute deviation)

# Filtering these in advance:

X <- as.matrix(expr[,-1])
mads <- apply(X, 1, mad, na.rm = TRUE)
bad  <- which(!is.finite(mads) | mads == 0)

length(bad)
head(expr[,1][bad])

mask <- mads > 0
expr <- expr[mask,]

# %%
dim(expr)

# %%
# Subset to genes in the top X percentile for generating modules

prob <- .2
mean_expr <- rowMeans(expr[,-1])

subset_cutoff <- unname(quantile(mean_expr, prob))
print(paste("quantile(mean_expr, prob):", round(subset_cutoff, 3)))
subset <- mean_expr >= subset_cutoff
sum(subset)

# %%
samplegroups <- as.factor(sampleinfo$age)
merge.param <- 0.95
projectname <- paste0("hahn_2023_cortex_STAR_TPM_All_94_outliers_removed", "_mergeParam", merge.param, "_subsetCutoff", round(subset_cutoff, 3))

# %%
FindModules(
  projectname=projectname,
  expr=expr,
  geneinfo=1,
  sampleindex=2:ncol(expr),
  samplegroups=samplegroups,
  subset=subset,
  simMat=NULL,
  saveSimMat=FALSE,
  simType="Bicor",
  beta=1,
  overlapType="None",
  TOtype="signed",
  TOdenom="min",
  MIestimator="mi.mm",
  MIdisc="equalfreq",
  signumType="rel",
  iterate=TRUE,
  signumvec=c(.96,.95,.94,.93,.92,.91,.9), 
  minsizevec=c(3,4,6,8,10), 
  signum=NULL,
  minSize=NULL,
  merge.by="ME",
  merge.param=merge.param,
  export.merge.comp=T,
  ZNCcut=2,
  calcSW=FALSE,
  loadTree=FALSE,
  writeKME=TRUE,
  calcBigModStat=FALSE,
  writeModSnap=TRUE
)
